# %% [markdown]
# # Importing Essential Libraries

# %%
import pandas as pd

# %% [markdown]
# # Reading CSV File

# %%
df=pd.read_csv('CANARA BANK--1308.csv')

# %%
df.shape
# Out:
# (4686, 6)

# %%
df.tail(5)
# Out:
#              DATE                                        DESCRIPTION    DEBIT  \
# 4681  07-Nov-2022            MOB-IMPS-CR SELVAMAUT Karur2461 chitra6      NaN
# 4682  07-Nov-2022  UPI CR 231140131016 Mr2461KRISHN CIUB s PaytoM 9b      NaN
# 4683  07-Nov-2022             NEFT2461Cr-58-RAJENDRAENTERPRISES- REF      NaN
# 4684  07-Nov-2022  IBITG478095700OnlineTransaction2461BDP-CNBNETC...  3561.95
# 4685  07-Nov-2022                 NEFT2461Cr-52-SRIKRISHNAAUTOPARTS-      NaN
#
#        CREDIT       BALANCE CLASSIFICATION_TRANS
# 4681  25089.0 -1.030645e+08                 IMPS
# 4682    784.0 -1.030637e+08                  UPI
# 4683   4563.0 -1.030591e+08                 NEFT
# 4684      NaN -1.030627e+08       ONLINE-PAYMENT
# 4685   7691.0 -1.030550e+08                 NEFT

# %%
df.dtypes
# Out:
# DATE                     object
# DESCRIPTION              object
# DEBIT                   float64
# CREDIT                  float64
# BALANCE                 float64
# CLASSIFICATION_TRANS     object
# dtype: object

# %% [markdown]
# ## Parsing Date

# %%
df['DATE'] = pd.to_datetime(df['DATE'], format="%d-%b-%Y", errors='coerce')

# %%
df.tail(10)
# Out:
#            DATE                                        DESCRIPTION    DEBIT  \
# 4676 2022-11-07                      NEFT2461Cr-93-SELVITYRES-null      NaN
# 4677 2022-11-07             NEFT2461Cr-15-DUBAIAUTOTYRES- ATTN TRF      NaN
# 4678 2022-11-07                     IBOAT3737753003054201000229OTH      NaN
# 4679 2022-11-07               RTGS2461Cr---PVJAUTOACCESSORIES-null      NaN
# 4680 2022-11-07  UPI CR 231110791488 MrK2461ALAG IDIB cbank UPI...      NaN
# 4681 2022-11-07            MOB-IMPS-CR SELVAMAUT Karur2461 chitra6      NaN
# 4682 2022-11-07  UPI CR 231140131016 Mr2461KRISHN CIUB s PaytoM 9b      NaN
# 4683 2022-11-07             NEFT2461Cr-58-RAJENDRAENTERPRISES- REF      NaN
# 4684 2022-11-07  IBITG478095700OnlineTransaction2461BDP-CNBNETC...  3561.95
# 4685 2022-11-07                 NEFT2461Cr-52-SRIKRISHNAAUTOPARTS-      NaN
#
#         CREDIT       BALANCE CLASSIFICATION_TRANS
# 4676   86320.0 -1.039995e+08                 NEFT
# 4677    6966.0 -1.039926e+08                 NEFT
# 4678  500000.0 -1.034926e+08             TRANSFER
# 4679  400000.0 -1.030926e+08                 RTGS
# 4680    3000.0 -1.030896e+08                  UPI
# 4681   25089.0 -1.030645e+08                 IMPS
# 4682     784.0 -1.030637e+08                  UPI
# 4683    4563.0 -1.030591e+08                 NEFT
# 4684       NaN -1.030627e+08       ONLINE-PAYMENT
# 4685    7691.0 -1.030550e+08                 NEFT

# %%
df.dtypes
# Out:
# DATE                    datetime64[ns]
# DESCRIPTION                     object
# DEBIT                          float64
# CREDIT                         float64
# BALANCE                        float64
# CLASSIFICATION_TRANS            object
# dtype: object

# %% [markdown]
# # Converting to numeric values

# %%
df['DEBIT'] = pd.to_numeric(df['DEBIT'], errors='coerce')
df['CREDIT'] = pd.to_numeric(df['CREDIT'], errors='coerce')
df['BALANCE'] = pd.to_numeric(df['BALANCE'], errors='coerce')

df.tail()
# Out:
#            DATE                                        DESCRIPTION    DEBIT  \
# 4681 2022-11-07            MOB-IMPS-CR SELVAMAUT Karur2461 chitra6      NaN
# 4682 2022-11-07  UPI CR 231140131016 Mr2461KRISHN CIUB s PaytoM 9b      NaN
# 4683 2022-11-07             NEFT2461Cr-58-RAJENDRAENTERPRISES- REF      NaN
# 4684 2022-11-07  IBITG478095700OnlineTransaction2461BDP-CNBNETC...  3561.95
# 4685 2022-11-07                 NEFT2461Cr-52-SRIKRISHNAAUTOPARTS-      NaN
#
#        CREDIT       BALANCE CLASSIFICATION_TRANS
# 4681  25089.0 -1.030645e+08                 IMPS
# 4682    784.0 -1.030637e+08                  UPI
# 4683   4563.0 -1.030591e+08                 NEFT
# 4684      NaN -1.030627e+08       ONLINE-PAYMENT
# 4685   7691.0 -1.030550e+08                 NEFT

# %%
df.dtypes
# Out:
# DATE                    datetime64[ns]
# DESCRIPTION                     object
# DEBIT                          float64
# CREDIT                         float64
# BALANCE                        float64
# CLASSIFICATION_TRANS            object
# dtype: object

# %% [markdown]
# ## Handling NaN

# %%
df['DEBIT'] = df['DEBIT'].fillna(0)
df['CREDIT'] = df['CREDIT'].fillna(0)
df['BALANCE'] = df['BALANCE'].fillna(0)

df.tail(5)
# Out:
#            DATE                                        DESCRIPTION    DEBIT  \
# 4681 2022-11-07            MOB-IMPS-CR SELVAMAUT Karur2461 chitra6     0.00
# 4682 2022-11-07  UPI CR 231140131016 Mr2461KRISHN CIUB s PaytoM 9b     0.00
# 4683 2022-11-07             NEFT2461Cr-58-RAJENDRAENTERPRISES- REF     0.00
# 4684 2022-11-07  IBITG478095700OnlineTransaction2461BDP-CNBNETC...  3561.95
# 4685 2022-11-07                 NEFT2461Cr-52-SRIKRISHNAAUTOPARTS-     0.00
#
#        CREDIT       BALANCE CLASSIFICATION_TRANS
# 4681  25089.0 -1.030645e+08                 IMPS
# 4682    784.0 -1.030637e+08                  UPI
# 4683   4563.0 -1.030591e+08                 NEFT
# 4684      0.0 -1.030627e+08       ONLINE-PAYMENT
# 4685   7691.0 -1.030550e+08                 NEFT

# %% [markdown]
# # Analyze Data

# %% [markdown]
# ## Calculate Total Income

# %%
Sum_credit = df['CREDIT'].sum()

print("Total Income:", Sum_credit)
# Out:
# Total Income: 158560228.05

# %% [markdown]
# ## Calculate Total Expenses

# %%
Sum_debit = df['DEBIT'].sum()

print("Total Expenses:", Sum_debit)
# Out:
# Total Expenses: 151512924.1

# %% [markdown]
# ## Identifying Frequent Transactions

# %%
top_frequent_transactions = df.groupby('DESCRIPTION').size().sort_values(ascending=False).head(5)

print("Top 5 Most Frequent Transaction Descriptions:")
print(top_frequent_transactions)
# Out:
# Top 5 Most Frequent Transaction Descriptions:
# DESCRIPTION
# ByClgCHNACCTSEC-TAMILNAD2461MERCANTILEBANKLTDTMBCHITHRAAGENCIES                142
# ByClgCHNACCTSEC-INDIAN2461OVERSEASBANKIOBCHITHRAAGENCIES                        98
# ByClgCHNACCTSEC-KARURVYSYA2461BANKLTDKVBCHITHRAAGENCIES                         67
# ByClgCHNACCTSEC-CITYUNION2461BANKLTDCHITHRAAGENCIES                             58
# ChqPaid-MICRInward2461Clearing-CASTROLINDIALTD-DEUTSCHEBANKDTB-DEUTSCHEBANK     47
# dtype: int64

# %%
df.dtypes
# Out:
# DATE                    datetime64[ns]
# DESCRIPTION                     object
# DEBIT                          float64
# CREDIT                         float64
# BALANCE                        float64
# CLASSIFICATION_TRANS            object
# dtype: object

# %% [markdown]
# # Report Generation

# %%
report_df = df[["DATE", "DEBIT", "CREDIT"]]

# %%
report_df.dtypes
# Out:
# DATE      datetime64[ns]
# DEBIT            float64
# CREDIT           float64
# dtype: object

# %%
report_df["DATE"] = report_df["DATE"].dt.strftime("%Y-%m")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1468\2599620418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   report_df["DATE"] = report_df["DATE"].dt.strftime("%Y-%m")

# %%
report_df
# Out:
#          DATE      DEBIT    CREDIT
# 0     2022-04    4425.00       0.0
# 1     2022-05       0.00  250000.0
# 2     2022-05  100000.00       0.0
# 3     2022-05    8100.00       0.0
# 4     2022-05       0.00    2853.0
# ...       ...        ...       ...
# 4681  2022-11       0.00   25089.0
# 4682  2022-11       0.00     784.0
# 4683  2022-11       0.00    4563.0
# 4684  2022-11    3561.95       0.0
# 4685  2022-11       0.00    7691.0
#
# [4686 rows x 3 columns]

# %%
report_df = report_df.groupby("DATE").sum().reset_index()

# %%
report_df.columns
# Out:
# Index(['DATE', 'DEBIT', 'CREDIT'], dtype='object')

# %%
report_df
# Out:
#       DATE        DEBIT       CREDIT
# 0  2022-04      4425.00         0.00
# 1  2022-05  22500888.34  27357705.05
# 2  2022-06  26951601.59  24379814.00
# 3  2022-07  25566985.43  23493548.00
# 4  2022-08  18407936.88  17191384.00
# 5  2022-09  26608456.19  17332162.00
# 6  2022-10  24688594.71  37262909.00
# 7  2022-11   6784035.96  11542706.00

# %%
balance_df = df[["DATE", "DEBIT", "CREDIT", "BALANCE"]]

# %%
balance_df
# Out:
#            DATE      DEBIT    CREDIT       BALANCE
# 0    2022-04-30    4425.00       0.0 -1.101067e+08
# 1    2022-05-01       0.00  250000.0 -1.098567e+08
# 2    2022-05-01  100000.00       0.0 -1.099567e+08
# 3    2022-05-02    8100.00       0.0 -1.099648e+08
# 4    2022-05-02       0.00    2853.0 -1.099620e+08
# ...         ...        ...       ...           ...
# 4681 2022-11-07       0.00   25089.0 -1.030645e+08
# 4682 2022-11-07       0.00     784.0 -1.030637e+08
# 4683 2022-11-07       0.00    4563.0 -1.030591e+08
# 4684 2022-11-07    3561.95       0.0 -1.030627e+08
# 4685 2022-11-07       0.00    7691.0 -1.030550e+08
#
# [4686 rows x 4 columns]

# %%
balance_df["DATE"] = balance_df["DATE"].dt.strftime("%Y-%m")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_1468\4038409200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   balance_df["DATE"] = balance_df["DATE"].dt.strftime("%Y-%m")

# %%
balance_df
# Out:
#          DATE      DEBIT    CREDIT       BALANCE
# 0     2022-04    4425.00       0.0 -1.101067e+08
# 1     2022-05       0.00  250000.0 -1.098567e+08
# 2     2022-05  100000.00       0.0 -1.099567e+08
# 3     2022-05    8100.00       0.0 -1.099648e+08
# 4     2022-05       0.00    2853.0 -1.099620e+08
# ...       ...        ...       ...           ...
# 4681  2022-11       0.00   25089.0 -1.030645e+08
# 4682  2022-11       0.00     784.0 -1.030637e+08
# 4683  2022-11       0.00    4563.0 -1.030591e+08
# 4684  2022-11    3561.95       0.0 -1.030627e+08
# 4685  2022-11       0.00    7691.0 -1.030550e+08
#
# [4686 rows x 4 columns]

# %%
## Finding last transaction balance of each month

final_balance = balance_df.groupby("DATE")["BALANCE"].last()

# %%
## merging final balance of each month with new dataframe

report_df["BALANCE"] = report_df["DATE"].map(final_balance)

# %%
report_df
# Out:
#       DATE        DEBIT       CREDIT       BALANCE
# 0  2022-04      4425.00         0.00 -1.101067e+08
# 1  2022-05  22500888.34  27357705.05 -1.052499e+08
# 2  2022-06  26951601.59  24379814.00 -1.078217e+08
# 3  2022-07  25566985.43  23493548.00 -1.098951e+08
# 4  2022-08  18407936.88  17191384.00 -1.111117e+08
# 5  2022-09  26608456.19  17332162.00 -1.203880e+08
# 6  2022-10  24688594.71  37262909.00 -1.078137e+08
# 7  2022-11   6784035.96  11542706.00 -1.030550e+08

# %%
## writing this dataframe to new csv file

df.to_csv('monthly_summary_CANARA_BANK.csv', index=False)

# %% [markdown]
# ## Identifying Frequent Transactions

# %%
top_frequent_transactions = df.groupby('DESCRIPTION').size().sort_values(ascending=False).head(5)

print("Top 5 Most Frequent Transaction Descriptions:")
print(top_frequent_transactions)
# Out:
# Top 5 Most Frequent Transaction Descriptions:
# DESCRIPTION
# ByClgCHNACCTSEC-TAMILNAD2461MERCANTILEBANKLTDTMBCHITHRAAGENCIES                142
# ByClgCHNACCTSEC-INDIAN2461OVERSEASBANKIOBCHITHRAAGENCIES                        98
# ByClgCHNACCTSEC-KARURVYSYA2461BANKLTDKVBCHITHRAAGENCIES                         67
# ByClgCHNACCTSEC-CITYUNION2461BANKLTDCHITHRAAGENCIES                             58
# ChqPaid-MICRInward2461Clearing-CASTROLINDIALTD-DEUTSCHEBANKDTB-DEUTSCHEBANK     47
# dtype: int64

# %% [markdown]
# ## Identifying Inconsistencies in BALANCE

# %%
balance = df.iloc[0]["BALANCE"]
credit = df.iloc[0]["CREDIT"]
debit = df.iloc[0]["DEBIT"]
initial_balance = balance - credit + debit

# %%
list_balance = []
current_balance = initial_balance

for index, row in report_df.iterrows():
    total_balance = current_balance + row["CREDIT"] - row["DEBIT"]
    list_balance.append(total_balance)
    current_balance = total_balance

# %%
list_balance
# Out:
# [np.float64(-110106720.84),
#  np.float64(-105249904.13000001),
#  np.float64(-107821691.72000001),
#  np.float64(-109895129.15),
#  np.float64(-111111682.03),
#  np.float64(-120387976.22),
#  np.float64(-107813661.93),
#  np.float64(-103054991.89)]

# %%
report_df["Calculated_Balance"] = list_balance
report_df
# Out:
#       DATE        DEBIT       CREDIT       BALANCE  Calculated_Balance
# 0  2022-04      4425.00         0.00 -1.101067e+08       -1.101067e+08
# 1  2022-05  22500888.34  27357705.05 -1.052499e+08       -1.052499e+08
# 2  2022-06  26951601.59  24379814.00 -1.078217e+08       -1.078217e+08
# 3  2022-07  25566985.43  23493548.00 -1.098951e+08       -1.098951e+08
# 4  2022-08  18407936.88  17191384.00 -1.111117e+08       -1.111117e+08
# 5  2022-09  26608456.19  17332162.00 -1.203880e+08       -1.203880e+08
# 6  2022-10  24688594.71  37262909.00 -1.078137e+08       -1.078137e+08
# 7  2022-11   6784035.96  11542706.00 -1.030550e+08       -1.030550e+08

# %% [markdown]
# ## Bonus Question(Finding inconsistency in balance)

# %%
# function to check for inconsistency
def check_inconsistency(row, previous_balance):
    i_balance = previous_balance - row['DEBIT'] + row['CREDIT']
    return abs(row['BALANCE'] - i_balance) <= 0.01


# Adding a column for inconsistency
previous_balance = initial_balance
inconsistencies = []

for _, row in df.iterrows():
    is_consistent = check_inconsistency(row, previous_balance)
    inconsistencies.append(is_consistent)
    previous_balance = row['BALANCE']  # Update the previous balance for the next row

df['Consistency'] = inconsistencies

df
# Out:
#            DATE                                        DESCRIPTION      DEBIT  \
# 0    2022-04-30           INET-IMPS-CR VINAYAKAA TAMILNAD2461M 884    4425.00
# 1    2022-05-01                      IBOAT352448003054201000229OTH       0.00
# 2    2022-05-01  IBOAT11111500023972610101372461OnlineTransacti...  100000.00
# 3    2022-05-02  ChqPaid-MICRInward2461Clearing-RAJKUMARPRINTER...    8100.00
# 4    2022-05-02  ByClgCHNACCTSEC-FEDERALBANK2461LTDFBLCHITRAAGE...       0.00
# ...         ...                                                ...        ...
# 4681 2022-11-07            MOB-IMPS-CR SELVAMAUT Karur2461 chitra6       0.00
# 4682 2022-11-07  UPI CR 231140131016 Mr2461KRISHN CIUB s PaytoM 9b       0.00
# 4683 2022-11-07             NEFT2461Cr-58-RAJENDRAENTERPRISES- REF       0.00
# 4684 2022-11-07  IBITG478095700OnlineTransaction2461BDP-CNBNETC...    3561.95
# 4685 2022-11-07                 NEFT2461Cr-52-SRIKRISHNAAUTOPARTS-       0.00
#
#         CREDIT       BALANCE CLASSIFICATION_TRANS  Consistency
# 0          0.0 -1.101067e+08                 IMPS         True
# 1     250000.0 -1.098567e+08             TRANSFER         True
# 2          0.0 -1.099567e+08             TRANSFER         True
# 3          0.0 -1.099648e+08                  CHQ         True
# 4       2853.0 -1.099620e+08                  CHQ         True
# ...        ...           ...                  ...          ...
# 4681   25089.0 -1.030645e+08                 IMPS         True
# 4682     784.0 -1.030637e+08                  UPI         True
# 4683    4563.0 -1.030591e+08                 NEFT         True
# 4684       0.0 -1.030627e+08       ONLINE-PAYMENT         True
# 4685    7691.0 -1.030550e+08                 NEFT         True
#
# [4686 rows x 7 columns]

# %%
# printing the rows where balance is inconsistent
df[df['Consistency'] == False]
# Out:
# Empty DataFrame
# Columns: [DATE, DESCRIPTION, DEBIT, CREDIT, BALANCE, CLASSIFICATION_TRANS, Consistency]
# Index: []
